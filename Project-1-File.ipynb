# %%
# Import Dependencies

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Locate Data Files

emissions_sector_path = "Resources/emissions-by-source/data.csv"

emissions_user_path= "Resources/by-end-user/data.csv"

# %%
# Read Data

sector_source = pd.read_csv(emissions_sector_path)

user_source = pd.read_csv(emissions_user_path)

# %%
# Sector Source 

sector_source.head()
# Out:
#   National Communication Sector National Communication Fuel IPCC Code  \
# 0                   Agriculture             Other emissions      3B24
# 1                   Agriculture             Other emissions      3B14
# 2                   Agriculture             Other emissions      3B14
# 3                   Agriculture             Other emissions      3D14
# 4                 Energy Supply                 Natural gas   1A1ciii
#
#   National Communication Fuel Group  \
# 0                   Other emissions
# 1                   Other emissions
# 2                   Other emissions
# 3                   Other emissions
# 4                     Gaseous fuels
#
#                      National Communication Category  \
# 0                                    Horses - wastes
# 1                                            Poultry
# 2                                    Horses - wastes
# 3                               Direct soil emission
# ...

# %%
# User Source

user_source.info()
user_source.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41508 entries, 0 to 41507
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   National Communication Category    41508 non-null  object
#  1   National Communication Fuel        41508 non-null  object
#  2   Measure type                       41508 non-null  object
#  3   Greenhouse Gas Group               41508 non-null  object
#  4   IPCC Code                          41508 non-null  object
#  5   Year                               41508 non-null  int64
#  6   National Communication Sub Sector  41508 non-null  object
#  7   Greenhouse Gas                     41508 non-null  object
#  8   Activity Name                      41508 non-null  object
#  9   National Communication Fuel Group  41508 non-null  object
#  10  Source                             41508 non-null  object
# ...

# %%
# Analyse Data 

sector_source.info()
sector_source.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44838 entries, 0 to 44837
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   National Communication Sector      44838 non-null  object
#  1   National Communication Fuel        44838 non-null  object
#  2   IPCC Code                          44838 non-null  object
#  3   National Communication Fuel Group  44838 non-null  object
#  4   National Communication Category    44838 non-null  object
#  5   National Communication Sub Sector  44838 non-null  object
#  6   Source                             44838 non-null  object
#  7   Greenhouse Gas Group               44838 non-null  object
#  8   Greenhouse Gas                     44838 non-null  object
#  9   Measure type                       44838 non-null  object
#  10  Activity Name                      44838 non-null  object
# ...

# %%
#  Analyse Data - Data Cleaning

#  As this is a large dataset, we can begin by removing the columns that we do not need. 

#    - Remove IPCC Code
#    - Remove Measure Type
#    - Remove Unit of Measure
#    - Remove National Communication Fuel
#    - Remove Greenhouse Gas
#    - Remove Greenhouse Gas Group
#    - Remove Source

# %%
# Analyse Data

# We need to compare the two datasets to ensure we're comparing like for like information. 

#sector_source["National Communication Sector"].unique()
#sector_source["Activity Name"].unique()
#sector_source["National Communication Fuel Group"].unique()
#sector_source["Year"].nunique()

# The above will give us information about the content within each column of data. We will now do the same for the other data set. 


#user_source["National Communication Sector"].unique()
#user_source["Activity Name"].unique()
#user_source["National Communication Fuel Group"].unique()
#user_source["Year"].nunique()
# Out:
# 30

# %% [markdown]
# Questions to consider
#
# - Are we going to total for the entire period of the dataset OR isolate one year and produce a report on that year? i.e. just 2019
#
#     - Doing just one year would make a like for like comparison better, but the reduction in data reduces possible visualisations
#     - Could do instead a 5 year period?
#
# - Do we need to use both datasets?
#
#     - A lot of overlapping data
#
# - Do we need to add Greenhouse Gas Groups in to provide further context for visualisation purposes? (Worried we don't have enough)

# %% [markdown]
# 1. Which Sector is responsible for most of our emissions in the UK?
#
# To answer this question we need to find:
#
# 1. The total emissions per Sector
#
# 2. Compare Sector v Sector results/total emissions
#
# 3. Display the information visually

# %%
# 1. Total emissions per sector 

# First we need to group total emissions by Sector 
# - To do this we need to group by Sector and get the value for Total Emissions 

# 2. Compare Sector v Sector results/total emissions

# Then we need to display the data to show us totals per Sector
# Then we need to analyse the data to determine the biggest producer of Total Emissions

# 3. Display the information visually 

# Once we have done this we can display the data in a piechart

# If we have a 5 year period, could also display a line chart of the past 5 years to see if there's been any change in top Sector 
# We could display what fuel type has been used most by each Sector

# %% [markdown]
# 2. Which End User is responsible for most of our emissions in the UK?
#
# To answer this question we need to find:
#
# - 1. We need to find the total emissions per User
#
# - 2. We need to compare User vs User emissions to compare and contrast
#
# - 3. We need to display the information in a visualisation, a pie chart would lend itself well to this data.

# %%
# 2. Which End User is responsible for most of our emissions in the UK? 

# To answer this question we need to find: 

# - 1. We need to find the Total Emissions per User

#     - Group by User and find value for Total Emissions

# - 2. We need to compare User vs User emissions to compare and contrast

#     - Analyse data and view the Total Emissions per User
#     - We know there a lot of Users so to make the data relevant we will decide to eliminate outliers 
#     - We decide to display the top 10 (we can discuss this) and then the rest under a category of 'Other'
#         - to create a category of 'Other' we would create a column and populate
#         it with the combined total of all of the Total Emissions of all Users 
#         outside of the Top 10. Ideally we'd want the top 10 to be > than 'Other'

# - 3. We need to display the information in a visualisation, a pie chart would lend itself well to this data. 

# We would present the information in a pie chart showing the Users that are responsible for most of our emissions in the UK 

#  If we have a 5 year period, could also display a line chart of the past 5 years to see if there's been any change in top User
#  We could display what fuel type has been used most by each User

# %% [markdown]
# Farjana

# %% [markdown]
# 4. When have emissions been highest in the UK?
#
# To anser this we need to compare the recorded year statistics

# %%
# 4. When have emissions been highest in the UK?

# To answer this we need to compare the recorded year statistics

# - First we need to find the Total Emissions per Year 
# - Then we need to display this information 
# - Then we can display this information visually 

# We can use a bar chart / line graph to show the Total Emissions per Year 
# We can also use a bar chart to show Fuel per Year to accompany the data
